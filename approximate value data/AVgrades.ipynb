# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

# Define the teams and years to loop through
teams = ["crd", "atl", "rav", "buf", "car", "chi", "cin", "cle", "dal", "den", "det", "gnb", "htx", "clt", "jax", "kan", "rai", "sdg", "ram", "mia", "min", "nwe", "nor", "nyg", "nyj", "phi", "pit", "sfo", "sea", "tam", "oti", "was"]
years = ["2013","2014","2015","2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]

# Function to scrape data
def scrape_data(team, year):
    # Adjust URL to include the team and year dynamically
    url = f"https://www.pro-football-reference.com/teams/{team}/{year}.htm"
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        # Extract the specific statistics
        stats = {
            'team': team,
            'year': year,
            'offensive_points_per_drive': None,
            'defensive_points_per_drive': None,
            'total_offense_points': None,
            'team_rush_yards': None,
            'team_total_yards': None,
            'team_passing_yards': None
        }
        
        body = soup.find('tbody')
        if body:
            for row in body.find_all('tr'):
                data_stat = row.find('th', {"scope": "row"})
                if data_stat and data_stat.text == "Team Stats":
                    stats['offensive_points_per_drive'] = row.find('td', {'data-stat': 'points_avg'}).text
                    stats['total_offense_points'] = row.find('td', {'data-stat': 'points'}).text
                    stats['team_total_yards'] = row.find('td', {'data-stat': 'total_yards'}).text
                    stats['team_passing_yards'] = row.find('td', {'data-stat': 'pass_yds'}).text
                    stats['team_rush_yards'] = row.find('td', {'data-stat': 'rush_yds'}).text
                elif data_stat and data_stat.text == "Opp. Stats":
                    stats['defensive_points_per_drive'] = row.find('td', {'data-stat': 'points_avg'}).text
                
        return stats
    else:
        print(f"Failed to retrieve data for {team} {year}")
        return None

# Loop through teams and years
all_data = []
for team in teams:
    for year in years:
        print(f"Scraping data for {team} {year}...")
        data = scrape_data(team, year)
        if data:
            all_data.append(data)
        time.sleep(4)  # Respectful delay to avoid overloading the server

# Create a DataFrame from the collected data
AVgrades = pd.DataFrame(all_data)

# Print the DataFrame
print(AVgrades)

# Save the DataFrame to a CSV file if needed
# df.to_csv('NFL_team_stats.csv', index=False)
# Out:
# Scraping data for crd 2013...
# Scraping data for crd 2014...
# Scraping data for crd 2015...
# Scraping data for crd 2016...
# Scraping data for crd 2017...
# Scraping data for crd 2018...
# Scraping data for crd 2019...
# Scraping data for crd 2020...
# Scraping data for crd 2021...
# Scraping data for crd 2022...
# Scraping data for crd 2023...
# Scraping data for atl 2013...
# Scraping data for atl 2014...
# Scraping data for atl 2015...
# Scraping data for atl 2016...
# Scraping data for atl 2017...
# Scraping data for atl 2018...
# Scraping data for atl 2019...
# Scraping data for atl 2020...
# Scraping data for atl 2021...
# Scraping data for atl 2022...
# Scraping data for atl 2023...
# Scraping data for rav 2013...
# Scraping data for rav 2014...
# Scraping data for rav 2015...
# Scraping data for rav 2016...
# Scraping data for rav 2017...
# Scraping data for rav 2018...
# Scraping data for rav 2019...
# Scraping data for rav 2020...
# Scraping data for rav 2021...
# Scraping data for rav 2022...
# Scraping data for rav 2023...
# Scraping data for buf 2013...
# Scraping data for buf 2014...
# Scraping data for buf 2015...
# Scraping data for buf 2016...
# Scraping data for buf 2017...
# Scraping data for buf 2018...
# Scraping data for buf 2019...
# Scraping data for buf 2020...
# Scraping data for buf 2021...
# Scraping data for buf 2022...
# Scraping data for buf 2023...
# Scraping data for car 2013...
# Scraping data for car 2014...
# Scraping data for car 2015...
# Scraping data for car 2016...
# Scraping data for car 2017...
# Scraping data for car 2018...
# Scraping data for car 2019...
# Scraping data for car 2020...
# Scraping data for car 2021...
# Scraping data for car 2022...
# Scraping data for car 2023...
# Scraping data for chi 2013...
# Scraping data for chi 2014...
# Scraping data for chi 2015...
# Scraping data for chi 2016...
# Scraping data for chi 2017...
# Scraping data for chi 2018...
# Scraping data for chi 2019...
# Scraping data for chi 2020...
# Scraping data for chi 2021...
# Scraping data for chi 2022...
# Scraping data for chi 2023...
# Scraping data for cin 2013...
# Scraping data for cin 2014...
# Scraping data for cin 2015...
# Scraping data for cin 2016...
# Scraping data for cin 2017...
# Scraping data for cin 2018...
# Scraping data for cin 2019...
# Scraping data for cin 2020...
# Scraping data for cin 2021...
# Scraping data for cin 2022...
# Scraping data for cin 2023...
# Scraping data for cle 2013...
# Scraping data for cle 2014...
# Scraping data for cle 2015...
# Scraping data for cle 2016...
# Scraping data for cle 2017...
# Scraping data for cle 2018...
# Scraping data for cle 2019...
# Scraping data for cle 2020...
# Scraping data for cle 2021...
# Scraping data for cle 2022...
# Scraping data for cle 2023...
# Scraping data for dal 2013...
# Scraping data for dal 2014...
# Scraping data for dal 2015...
# Scraping data for dal 2016...
# Scraping data for dal 2017...
# Scraping data for dal 2018...
# Scraping data for dal 2019...
# Scraping data for dal 2020...
# Scraping data for dal 2021...
# Scraping data for dal 2022...
# Scraping data for dal 2023...
# Scraping data for den 2013...
# Scraping data for den 2014...
# Scraping data for den 2015...
# Scraping data for den 2016...
# Scraping data for den 2017...
# Scraping data for den 2018...
# Scraping data for den 2019...
# Scraping data for den 2020...
# Scraping data for den 2021...
# Scraping data for den 2022...
# Scraping data for den 2023...
# Scraping data for det 2013...
# Scraping data for det 2014...
# Scraping data for det 2015...
# Scraping data for det 2016...
# Scraping data for det 2017...
# Scraping data for det 2018...
# Scraping data for det 2019...
# Scraping data for det 2020...
# Scraping data for det 2021...
# Scraping data for det 2022...
# Scraping data for det 2023...
# Scraping data for gnb 2013...
# Scraping data for gnb 2014...
# Scraping data for gnb 2015...
# Scraping data for gnb 2016...
# Scraping data for gnb 2017...
# Scraping data for gnb 2018...
# Scraping data for gnb 2019...
# Scraping data for gnb 2020...
# Scraping data for gnb 2021...
# Scraping data for gnb 2022...
# Scraping data for gnb 2023...
# Scraping data for htx 2013...
# Scraping data for htx 2014...
# Scraping data for htx 2015...
# Scraping data for htx 2016...
# Scraping data for htx 2017...
# Scraping data for htx 2018...
# Scraping data for htx 2019...
# Scraping data for htx 2020...
# Scraping data for htx 2021...
# Scraping data for htx 2022...
# Scraping data for htx 2023...
# Scraping data for clt 2013...
# Scraping data for clt 2014...
# Scraping data for clt 2015...
# Scraping data for clt 2016...
# Scraping data for clt 2017...
# Scraping data for clt 2018...
# Scraping data for clt 2019...
# Scraping data for clt 2020...
# Scraping data for clt 2021...
# Scraping data for clt 2022...
# Scraping data for clt 2023...
# Scraping data for jax 2013...
# Scraping data for jax 2014...
# Scraping data for jax 2015...
# Scraping data for jax 2016...
# Scraping data for jax 2017...
# Scraping data for jax 2018...
# Scraping data for jax 2019...
# Scraping data for jax 2020...
# Scraping data for jax 2021...
# Scraping data for jax 2022...
# Scraping data for jax 2023...
# Scraping data for kan 2013...
# Scraping data for kan 2014...
# Scraping data for kan 2015...
# Scraping data for kan 2016...
# Scraping data for kan 2017...
# Scraping data for kan 2018...
# Scraping data for kan 2019...
# Scraping data for kan 2020...
# Scraping data for kan 2021...
# Scraping data for kan 2022...
# Scraping data for kan 2023...
# Scraping data for rai 2013...
# Scraping data for rai 2014...
# Scraping data for rai 2015...
# Scraping data for rai 2016...
# Scraping data for rai 2017...
# Scraping data for rai 2018...
# Scraping data for rai 2019...
# Scraping data for rai 2020...
# Scraping data for rai 2021...
# Scraping data for rai 2022...
# Scraping data for rai 2023...
# Scraping data for sdg 2013...
# Scraping data for sdg 2014...
# Scraping data for sdg 2015...
# Scraping data for sdg 2016...
# Scraping data for sdg 2017...
# Scraping data for sdg 2018...
# Scraping data for sdg 2019...
# Scraping data for sdg 2020...
# Scraping data for sdg 2021...
# Scraping data for sdg 2022...
# Scraping data for sdg 2023...
# Scraping data for ram 2013...
# Scraping data for ram 2014...
# Scraping data for ram 2015...
# Scraping data for ram 2016...
# Scraping data for ram 2017...
# Scraping data for ram 2018...
# Scraping data for ram 2019...
# Scraping data for ram 2020...
# Scraping data for ram 2021...
# Scraping data for ram 2022...
# Scraping data for ram 2023...
# Scraping data for mia 2013...
# Scraping data for mia 2014...
# Scraping data for mia 2015...
# Scraping data for mia 2016...
# Scraping data for mia 2017...
# Scraping data for mia 2018...
# Scraping data for mia 2019...
# Scraping data for mia 2020...
# Scraping data for mia 2021...
# Scraping data for mia 2022...
# Scraping data for mia 2023...
# Scraping data for min 2013...
# Scraping data for min 2014...
# Scraping data for min 2015...
# Scraping data for min 2016...
# Scraping data for min 2017...
# Scraping data for min 2018...
# Scraping data for min 2019...
# Scraping data for min 2020...
# Scraping data for min 2021...
# Scraping data for min 2022...
# Scraping data for min 2023...
# Scraping data for nwe 2013...
# Scraping data for nwe 2014...
# Scraping data for nwe 2015...
# Scraping data for nwe 2016...
# Scraping data for nwe 2017...
# Scraping data for nwe 2018...
# Scraping data for nwe 2019...
# Scraping data for nwe 2020...
# Scraping data for nwe 2021...
# Scraping data for nwe 2022...
# Scraping data for nwe 2023...
# Scraping data for nor 2013...
# Scraping data for nor 2014...
# Scraping data for nor 2015...
# Scraping data for nor 2016...
# Scraping data for nor 2017...
# Scraping data for nor 2018...
# Scraping data for nor 2019...
# Scraping data for nor 2020...
# Scraping data for nor 2021...
# Scraping data for nor 2022...
# Scraping data for nor 2023...
# Scraping data for nyg 2013...
# Scraping data for nyg 2014...
# Scraping data for nyg 2015...
# Scraping data for nyg 2016...
# Scraping data for nyg 2017...
# Scraping data for nyg 2018...
# Scraping data for nyg 2019...
# Scraping data for nyg 2020...
# Scraping data for nyg 2021...
# Scraping data for nyg 2022...
# Scraping data for nyg 2023...
# Scraping data for nyj 2013...
# Scraping data for nyj 2014...
# Scraping data for nyj 2015...
# Scraping data for nyj 2016...
# Scraping data for nyj 2017...
# Scraping data for nyj 2018...
# Scraping data for nyj 2019...
# Scraping data for nyj 2020...
# Scraping data for nyj 2021...
# Scraping data for nyj 2022...
# Scraping data for nyj 2023...
# Scraping data for phi 2013...
# Scraping data for phi 2014...
# Scraping data for phi 2015...
# Scraping data for phi 2016...
# Scraping data for phi 2017...
# Scraping data for phi 2018...
# Scraping data for phi 2019...
# Scraping data for phi 2020...
# Scraping data for phi 2021...
# Scraping data for phi 2022...
# Scraping data for phi 2023...
# Scraping data for pit 2013...
# Scraping data for pit 2014...
# Scraping data for pit 2015...
# Scraping data for pit 2016...
# Scraping data for pit 2017...
# Scraping data for pit 2018...
# Scraping data for pit 2019...
# Scraping data for pit 2020...
# Scraping data for pit 2021...
# Scraping data for pit 2022...
# Scraping data for pit 2023...
# Scraping data for sfo 2013...
# Scraping data for sfo 2014...
# Scraping data for sfo 2015...
# Scraping data for sfo 2016...
# Scraping data for sfo 2017...
# Scraping data for sfo 2018...
# Scraping data for sfo 2019...
# Scraping data for sfo 2020...
# Scraping data for sfo 2021...
# Scraping data for sfo 2022...
# Scraping data for sfo 2023...
# Scraping data for sea 2013...
# Scraping data for sea 2014...
# Scraping data for sea 2015...
# Scraping data for sea 2016...
# Scraping data for sea 2017...
# Scraping data for sea 2018...
# Scraping data for sea 2019...
# Scraping data for sea 2020...
# Scraping data for sea 2021...
# Scraping data for sea 2022...
# Scraping data for sea 2023...
# Scraping data for tam 2013...
# Scraping data for tam 2014...
# Scraping data for tam 2015...
# Scraping data for tam 2016...
# Scraping data for tam 2017...
# Scraping data for tam 2018...
# Scraping data for tam 2019...
# Scraping data for tam 2020...
# Scraping data for tam 2021...
# Scraping data for tam 2022...
# Scraping data for tam 2023...
# Scraping data for oti 2013...
# Scraping data for oti 2014...
# Scraping data for oti 2015...
# Scraping data for oti 2016...
# Scraping data for oti 2017...
# Scraping data for oti 2018...
# Scraping data for oti 2019...
# Scraping data for oti 2020...
# Scraping data for oti 2021...
# Scraping data for oti 2022...
# Scraping data for oti 2023...
# Scraping data for was 2013...
# Scraping data for was 2014...
# Scraping data for was 2015...
# Scraping data for was 2016...
# Scraping data for was 2017...
# Scraping data for was 2018...
# Scraping data for was 2019...
# Scraping data for was 2020...
# Scraping data for was 2021...
# Scraping data for was 2022...
# Scraping data for was 2023...
#     team  year offensive_points_per_drive defensive_points_per_drive  \
# 0    crd  2013                       1.71                       1.53
# 1    crd  2014                       1.52                       1.55
# 2    crd  2015                       2.37                       1.66
# 3    crd  2016                       2.03                       1.76
# 4    crd  2017                       1.41                       1.69
# ..   ...   ...                        ...                        ...
# 347  was  2019                       1.50                       2.38
# 348  was  2020                       1.74                       1.69
# 349  was  2021                       1.80                       2.36
# 350  was  2022                       1.55                       1.68
# 351  was  2023                       1.68                       2.53
#
#     total_offense_points team_rush_yards team_total_yards team_passing_yards
# 0                    379            1540             5542               4002
# 1                    310            1308             5116               3808
# 2                    489            1917             6533               4616
# 3                    418            1732             5868               4136
# 4                    295            1386             5026               3640
# ..                   ...             ...              ...                ...
# 347                  266            1583             4395               2812
# 348                  335            1611             5076               3465
# 349                  335            2061             5502               3441
# 350                  321            2143             5615               3472
# 351                  329            1592             5317               3725
#
# [352 rows x 8 columns]

# %%
AVgrades = AVgrades.sort_values(by=['year','team'])
# List of columns to convert
columns_to_convert = ['year', 'offensive_points_per_drive', 'defensive_points_per_drive', 'total_offense_points', 'team_rush_yards', 'team_total_yards', 'team_passing_yards']

# Converting columns
AVgrades[columns_to_convert] = AVgrades[columns_to_convert].apply(pd.to_numeric, errors='coerce')

AVgrades['league_avg_offensive_points_per_drive'] = AVgrades.groupby('year')['offensive_points_per_drive'].transform('mean')
AVgrades['league_avg_defensive_points_per_drive'] = AVgrades.groupby('year')['defensive_points_per_drive'].transform('mean')

AVgrades["team_offense_points"] = (100 * AVgrades['offensive_points_per_drive']) / AVgrades['league_avg_offensive_points_per_drive']
AVgrades["team_points_for_o_line"] = (5/11) * AVgrades["team_offense_points"]
AVgrades["team_points_for_skill_positions"] = AVgrades["team_offense_points"] - AVgrades["team_points_for_o_line"]
AVgrades["team_points_for_rushers"] = AVgrades["team_points_for_skill_positions"] * 0.22 * (AVgrades["team_rush_yards"]/AVgrades["team_total_yards"]) / 0.37
AVgrades["team_points_for_passers"] = (AVgrades["team_points_for_skill_positions"] - AVgrades["team_points_for_rushers"]) * 0.26
AVgrades["team_points_for_receivers"] = (AVgrades["team_points_for_skill_positions"] - AVgrades["team_points_for_rushers"]) * 0.74
AVgrades["M"] = AVgrades["defensive_points_per_drive"] / AVgrades['league_avg_defensive_points_per_drive']
AVgrades["team_defense_points"] = 100 * ((1+2*AVgrades["M"]-AVgrades["M"]**2) / (2*AVgrades["M"]))
unnamed_cols = [col for col in AVgrades.columns if 'Unnamed' in col]
AVgrades = AVgrades.drop(columns=unnamed_cols)

AVgrades
# Out:
#     team  year  offensive_points_per_drive  defensive_points_per_drive  \
# 11   atl  2013                        1.85                        2.38
# 33   buf  2013                        1.48                        1.68
# 44   car  2013                        1.99                        1.33
# 55   chi  2013                        2.16                        2.36
# 66   cin  2013                        1.91                        1.39
# ..   ...   ...                         ...                         ...
# 197  sdg  2023                        1.78                        2.01
# 318  sea  2023                        1.93                        2.20
# 307  sfo  2023                        2.70                        1.71
# 329  tam  2023                        1.85                        1.78
# 351  was  2023                        1.68                        2.53
#
#      total_offense_points  team_rush_yards  team_total_yards  \
# 11                    353             1247              5490
# 33                    339             2307              5410
# 44                    366             2026              5069
# 55                    445             1828              6109
# 66                    430             1755              5891
# ..                    ...              ...               ...
# 197                   346             1642              5599
# 318                   364             1580              5490
# 307                   491             2389              6773
# 329                   348             1509              5321
# 351                   329             1592              5317
#
#      team_passing_yards  league_avg_offensive_points_per_drive  \
# 11                 4243                                1.81375
# 33                 3103                                1.81375
# 44                 3043                                1.81375
# 55                 4281                                1.81375
# 66                 4136                                1.81375
# ..                  ...                                    ...
# 197                3957                                1.89000
# 318                3910                                1.89000
# 307                4384                                1.89000
# 329                3812                                1.89000
# 351                3725                                1.89000
#
#      league_avg_defensive_points_per_drive  team_offense_points  \
# 11                                1.810000           101.998622
# 33                                1.810000            81.598897
# 44                                1.810000           109.717436
# 55                                1.810000           119.090283
# 66                                1.810000           105.306685
# ..                                     ...                  ...
# 197                               1.884688            94.179894
# 318                               1.884688           102.116402
# 307                               1.884688           142.857143
# 329                               1.884688            97.883598
# 351                               1.884688            88.888889
#
#      team_points_for_o_line  team_points_for_skill_positions  \
# 11                46.363010                        55.635612
# 33                37.090408                        44.508489
# 44                49.871562                        59.845874
# 55                54.131947                        64.958336
# 66                47.866675                        57.440010
# ..                      ...                              ...
# 197               42.809043                        51.370851
# 318               46.416546                        55.699856
# 307               64.935065                        77.922078
# 329               44.492544                        53.391053
# 351               40.404040                        48.484848
#
#      team_points_for_rushers  team_points_for_passers  \
# 11                  7.513944                12.511634
# 33                 11.285327                 8.638022
# 44                 14.222381                11.862108
# 55                 11.557447                13.884231
# 66                 10.174746                12.288969
# ..                       ...                      ...
# 197                 8.957780                11.027398
# 318                 9.531467                12.003781
# 307                16.342427                16.010709
# 329                 9.002962                11.540904
# 351                 8.631840                10.361782
#
#      team_points_for_receivers         M  team_defense_points
# 11                   35.610034  1.314917            72.279354
# 33                   24.585140  0.928177           107.460208
# 44                   33.761385  0.734807           131.304781
# 55                   39.516658  1.303867            73.154087
# 66                   34.976296  0.767956           126.710124
# ..                         ...       ...                  ...
# 197                  31.385673  1.066490            93.558283
# 318                  34.164607  1.167302            84.468693
# 307                  45.568942  0.907312           109.742211
# 329                  32.847187  0.944454           105.717977
# 351                  29.491226  1.342398            70.126908
#
# [352 rows x 18 columns]

# %%
AVgrades["team_receiving_yards"] = AVgrades["team_passing_yards"]

# %%
AVgrades = AVgrades.rename(columns={'team_points_for_o_line': 'oline', 'team_points_for_rushers': 'rb', 'team_points_for_passers': 'qb', 'team_points_for_receivers':'wrte', 'team_defense_points':'dst', 'year':'season'})
AVgrades.to_csv("AVgrades.csv")

# %%
AVgrades1 = AVgrades[['team','oline','qb','rb','wrte','dst','season']]
AVgrades1.to_csv("AVbyPositionGroup.csv")
